# %%
# %matplotlib inline

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
from matplotlib import rc

# %%
rc('font',size=16)

# %%
# !ls
# Out:
# alpha.png		 dalphadr.png		monopole_gr.dat
# Catch2			 dalphadt.png		monpole-test.ipynb
# CMakeCache.txt		 DartConfiguration.tcl	parthenon
# CMakeFiles		 dbetadr.png		rho.png
# cmake_install.cmake	 dbetadt.png		singularity-eos
# compile_commands.json	 dKdr.png		singularity-opac
# CPackConfig.cmake	 dKdt.png		S.png
# CPackSourceConfig.cmake  grr.png		src
# CTestTestfile.cmake	 jr.png			Testing
# dadr.png		 Krr.png		tst
# dadt.png		 Makefile		vr.png

# %%
data = np.loadtxt('monopole_gr.dat')

# %%
# !head -n 1 gr1d.dat
# Out:
# head: cannot open 'gr1d.dat' for reading: No such file or directory

# %%
data[0]
# Out:
# array([ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,  7.43190071e-01,
#         3.86592014e-08, -0.00000000e+00,  3.86592014e-10,  1.28864005e-10,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  0.00000000e+00, -0.00000000e+00])

# %%
data[-1]
# Out:
# array([ 2.56000000e+02,  1.09899970e+00, -7.08360662e-05,  9.42492749e-01,
#         1.10934149e-46, -2.83991422e-46,  1.10934149e-48,  3.69780498e-49,
#        -2.13560029e-04,  8.30110151e-07,  2.24637698e-04, -6.47256851e-05,
#         4.13437665e-07, -3.64409413e-06,  8.30110151e-07, -2.17570611e-05])

# %%
plt.plot(data[...,0],data[...,1]**2)
plt.xlabel('r')
plt.ylabel(r'$g_{rr}$')
plt.savefig('grr.png')

# %%
plt.plot(data[...,0],(data[...,2]))
plt.xlabel('r')
plt.ylabel(r'$K^r_r$')
plt.savefig('Krr.png')

# %%
plt.plot(data[...,0],np.abs(data[...,3]))
plt.xlabel('r')
plt.ylabel(r'$\alpha$')
plt.savefig('alpha.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,4])
plt.xlabel('r')
plt.ylabel(r'$\rho$')
plt.savefig('rho.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,5])
plt.xlabel('r')
plt.ylabel(r'$j^r$')
plt.savefig('jr.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,6],label='trace')
plt.plot(data[...,0],data[...,7],label='(r,r)-component')
plt.xlabel('r')
plt.ylabel(r'$S$')
plt.legend()
plt.savefig('S.png')

# %%
plt.plot(data[...,0],data[...,8])
plt.xlabel('r')
plt.ylabel(r'$\partial a/\partial r$')
plt.savefig('dadr.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,9])
plt.xlabel('r')
plt.ylabel(r'$\partial K/\partial r$')
plt.savefig('dKdr.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,10])
plt.xlabel('r')
plt.ylabel(r'$\partial \alpha/\partial r$')
plt.savefig('dalphadr.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,11])
plt.xlabel('r')
plt.ylabel(r'$\partial \beta/\partial r$')
plt.savefig('dbetadr.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,12])
plt.xlabel('r')
plt.ylabel(r'$\partial a/\partial t$')
plt.savefig('dadt.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,13])
plt.xlabel('r')
plt.ylabel(r'$\partial \alpha/\partial t$')
plt.savefig('dalphadt.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,14])
plt.xlabel('r')
plt.ylabel(r'$\partial K/\partial t$')
plt.savefig('dKdt.png',bbox_inches='tight')

# %%
plt.plot(data[...,0],data[...,15])
plt.xlabel('r')
plt.ylabel(r'$\partial \beta/\partial t$')
plt.savefig('dbetadt.png',bbox_inches='tight')
